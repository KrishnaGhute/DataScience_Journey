# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

def get_displayed_date(date):
    url = f"https://tnagriculture.in/ARS/home/reservoir/{date}"
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    span = soup.find("span", class_="alert alert-danger")
    if span:
        text = span.get_text(strip=True)
        return text.replace("DATE :-", "").strip()
    return None

def find_first_real_date():
    current = datetime(2010, 1, 1)  # start from 2010
    end = datetime.now()            # today

    while current <= end:
        date_str = current.strftime("%Y-%m-%d")
        displayed = get_displayed_date(date_str)

        # If displayed date matches requested date, it's real
        if displayed == current.strftime("%d-%m-%Y"):
            return date_str

        current += timedelta(days=1)

    return None

first_real_date = find_first_real_date()
print("First date data is available:", first_real_date)
# Out:
# First date data is available: 2010-01-01

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def get_data_for_date(date):
    url = f"https://tnagriculture.in/ARS/home/reservoir/{date}"
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    tds = soup.find_all("td")
    data = []

    for i in range(0, len(tds), 9):
        row = tds[i:i+9]
        if len(row) < 9:
            continue
        
        values = [x.get_text(strip=True) for x in row]
        data.append([
            date,
            values[0],  # Reservoir name
            values[1],  # Full Depth
            values[2],  # Full Capacity
            values[3],  # Current Year Level
            values[4],  # Current Year Storage
            values[5],  # Inflow
            values[6],  # Outflow
            values[7],  # Last Year Level
            values[8],  # Last Year Storage
        ])

    return data

# Generate dates for January 2024
start = datetime(2024, 1, 1)
end = datetime(2024, 1, 31)

all_data = []

current = start
while current <= end:
    date_str = current.strftime("%Y-%m-%d")
    all_data += get_data_for_date(date_str)
    current += timedelta(days=1)

# Create dataframe
df = pd.DataFrame(all_data, columns=[
    "Date", "Reservoirs", "Full Depth(Feet)", "Full Capacity(M.Cft.)",
    "Current Year Level(Feet)", "Current Year Storage(M.Cft.)",
    "Current Year Inflow(CuSecs)", "Current Year Outflow(CuSecs.)",
    "Last Year Level(Feet)", "Last Year Storage(M.Cft.)"
])

# Save to CSV
df.to_csv("January_2024_dam_data.csv", index=False)

print("Data saved successfully! Total rows:", len(df))
# Out:
# Data saved successfully! Total rows: 589

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

def has_data(date):
    url = f"https://tnagriculture.in/ARS/home/reservoir/{date}"
    r = requests.get(url)
    if r.status_code != 200:
        return False

    soup = BeautifulSoup(r.text, "html.parser")
    tds = soup.find_all("td")
    return len(tds) > 0

def year_exists(year):
    dates = [f"{year}-01-01", f"{year}-06-01", f"{year}-12-01"]
    for d in dates:
        if has_data(d):
            return True
    return False

# 1) Find years with data
years = []
for y in range(2010, 2031):
    if year_exists(y):
        years.append(y)

print("Years with data:", years)

# 2) Create continuous ranges
ranges = []
start = years[0]
prev = years[0]

for y in years[1:]:
    if y == prev + 1:
        prev = y
    else:
        ranges.append((start, prev))
        start = y
        prev = y

ranges.append((start, prev))

print("Continuous ranges of data present:")
for r in ranges:
    print(r[0], "to", r[1])

# 3) Find last date available
def find_last_date():
    current = datetime(2030, 12, 31)  # start from far future
    end = datetime(2010, 1, 1)        # stop limit

    while current >= end:
        date_str = current.strftime("%Y-%m-%d")
        if has_data(date_str):
            return date_str
        current -= timedelta(days=1)

    return None

last_date = find_last_date()
print("Last date data is available:", last_date)
# Out:
# Years with data: [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]
# Continuous ranges of data present:
# 2010 to 2030
# Last date data is available: 2030-12-31

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

def get_data_for_date(date):
    url = f"https://tnagriculture.in/ARS/home/reservoir/{date}"
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "html.parser")

    # Find all td elements in table
    tds = soup.find_all("td")

    # Each row has 9 columns
    data = []
    for i in range(0, len(tds), 9):
        row = tds[i:i+9]
        if len(row) < 9:
            continue
        
        # Extract text
        values = [x.get_text(strip=True) for x in row]
        
        # Add date + row
        data.append([
            date,
            values[0],  # Reservoir name
            values[1],  # Full Depth
            values[2],  # Full Capacity
            values[3],  # Current Year Level
            values[4],  # Current Year Storage
            values[5],  # Inflow
            values[6],  # Outflow
            values[7],  # Last Year Level
            values[8],  # Last Year Storage
        ])

    return data

# Test with one date
date = "2024-01-01"
data = get_data_for_date(date)

df = pd.DataFrame(data, columns=[
    "Date", "Reservoirs", "Full Depth(Feet)", "Full Capacity(M.Cft.)",
    "Current Year Level(Feet)", "Current Year Storage(M.Cft.)",
    "Current Year Inflow(CuSecs)", "Current Year Outflow(CuSecs.)",
    "Last Year Level(Feet)", "Last Year Storage(M.Cft.)"
])

df.head()
# Out:
#          Date          Reservoirs Full Depth(Feet) Full Capacity(M.Cft.)  \
# 0  2024-01-01              METTUR              120                 93470
# 1  2024-01-01  Krishna Raja Sagar            124.8                 49452
# 2  2024-01-01              Kabini               65                 19516
# 3  2024-01-01             Harangi              129                  8500
# 4  2024-01-01           Hemavathy              117                 37103
#
#   Current Year Level(Feet) Current Year Storage(M.Cft.)  \
# 0                    71.27                        33801
# 1                    96.81                        20412
# 2                    54.29                        13357
# 3                   100.63                         3371
# 4                    86.66                        14985
#
#   Current Year Inflow(CuSecs) Current Year Outflow(CuSecs.)  \
# 0                         807                           252
# 1                         661                           975
# 2                         118                           300
# 3                         154                           100
# 4                         263                           350
#
#   Last Year Level(Feet) Last Year Storage(M.Cft.)
# 0                118.79                     91554
# 1                118.94                     41717
# 2                 52.35                     12352
# 3                 98.01                      3237
# 4                103.57                     25618

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta
import time

def get_data_for_date(date):
    url = f"https://tnagriculture.in/ARS/home/reservoir/{date}"
    r = requests.get(url)

    # If website is down or page not found
    if r.status_code != 200:
        return []

    soup = BeautifulSoup(r.text, "html.parser")
    tds = soup.find_all("td")

    data = []
    for i in range(0, len(tds), 9):
        row = tds[i:i+9]
        if len(row) < 9:
            continue

        values = [x.get_text(strip=True) for x in row]
        data.append([
            date,
            values[0],  # Reservoir name
            values[1],  # Full Depth
            values[2],  # Full Capacity
            values[3],  # Current Year Level
            values[4],  # Current Year Storage
            values[5],  # Inflow
            values[6],  # Outflow
            values[7],  # Last Year Level
            values[8],  # Last Year Storage
        ])

    return data

# ------------------ MAIN SCRAPER ------------------

start_date = datetime(2022, 5, 26)
end_date = datetime(2025, 12, 31)

all_data = []
current_date = start_date

while current_date <= end_date:
    date_str = current_date.strftime("%Y-%m-%d")
    daily_data = get_data_for_date(date_str)

    if daily_data:
        all_data.extend(daily_data)
        print(f"Data added for: {date_str}  -> {len(daily_data)} rows")

    # Move to next day
    current_date += timedelta(days=1)

    # Sleep to avoid blocking (important for websites)
    time.sleep(0.5)

# ------------------ SAVE TO CSV ------------------

df = pd.DataFrame(all_data, columns=[
    "Date", "Reservoirs", "Full Depth(Feet)", "Full Capacity(M.Cft.)",
    "Current Year Level(Feet)", "Current Year Storage(M.Cft.)",
    "Current Year Inflow(CuSecs)", "Current Year Outflow(CuSecs.)",
    "Last Year Level(Feet)", "Last Year Storage(M.Cft.)"
])

df.to_csv("dam_data_2015_2025.csv", index=False)
print("✅ Saved as dam_data_2015_2025.csv")
print("Total rows:", len(df))
# Out:
# Data added for: 2022-05-26  -> 19 rows
# Data added for: 2022-05-27  -> 19 rows
# Data added for: 2022-05-28  -> 19 rows
# Data added for: 2022-05-29  -> 19 rows
# Data added for: 2022-05-30  -> 19 rows
# Data added for: 2022-05-31  -> 19 rows
# Data added for: 2022-06-01  -> 19 rows
# Data added for: 2022-06-02  -> 19 rows
# Data added for: 2022-06-03  -> 19 rows
# Data added for: 2022-06-04  -> 19 rows
# Data added for: 2022-06-05  -> 19 rows
# Data added for: 2022-06-06  -> 19 rows
# Data added for: 2022-06-07  -> 19 rows
# Data added for: 2022-06-08  -> 19 rows
# Data added for: 2022-06-09  -> 19 rows
# Data added for: 2022-06-10  -> 19 rows
# Data added for: 2022-06-11  -> 19 rows
# Data added for: 2022-06-12  -> 19 rows
# Data added for: 2022-06-13  -> 19 rows
# Data added for: 2022-06-14  -> 19 rows
# Data added for: 2022-06-15  -> 19 rows
# Data added for: 2022-06-16  -> 19 rows
# Data added for: 2022-06-17  -> 19 rows
# Data added for: 2022-06-18  -> 19 rows
# Data added for: 2022-06-19  -> 19 rows
# Data added for: 2022-06-20  -> 19 rows
# Data added for: 2022-06-21  -> 19 rows
# Data added for: 2022-06-22  -> 19 rows
# Data added for: 2022-06-23  -> 19 rows
# Data added for: 2022-06-24  -> 19 rows
# Data added for: 2022-06-25  -> 19 rows
# Data added for: 2022-06-26  -> 19 rows
# Data added for: 2022-06-27  -> 19 rows
# Data added for: 2022-06-28  -> 19 rows
# Data added for: 2022-06-29  -> 19 rows
# Data added for: 2022-06-30  -> 19 rows
# Data added for: 2022-07-01  -> 19 rows
# Data added for: 2022-07-02  -> 19 rows
# Data added for: 2022-07-03  -> 19 rows
# Data added for: 2022-07-04  -> 19 rows
# Data added for: 2022-07-05  -> 19 rows
# Data added for: 2022-07-06  -> 19 rows
# Data added for: 2022-07-07  -> 19 rows
# Data added for: 2022-07-08  -> 19 rows
# Data added for: 2022-07-09  -> 19 rows
# Data added for: 2022-07-10  -> 19 rows
# Data added for: 2022-07-11  -> 19 rows
# Data added for: 2022-07-12  -> 19 rows
# Data added for: 2022-07-13  -> 19 rows
# Data added for: 2022-07-14  -> 19 rows
# Data added for: 2022-07-15  -> 19 rows
# Data added for: 2022-07-16  -> 19 rows
# Data added for: 2022-07-17  -> 19 rows
# Data added for: 2022-07-18  -> 19 rows
# Data added for: 2022-07-19  -> 19 rows
# Data added for: 2022-07-20  -> 19 rows
# Data added for: 2022-07-21  -> 19 rows
# Data added for: 2022-07-22  -> 19 rows
# Data added for: 2022-07-23  -> 19 rows
# Data added for: 2022-07-24  -> 19 rows
# Data added for: 2022-07-25  -> 19 rows
# Data added for: 2022-07-26  -> 19 rows
# Data added for: 2022-07-27  -> 19 rows
# Data added for: 2022-07-28  -> 19 rows
# Data added for: 2022-07-29  -> 19 rows
# Data added for: 2022-07-30  -> 19 rows
# Data added for: 2022-07-31  -> 19 rows
# Data added for: 2022-08-01  -> 19 rows
# Data added for: 2022-08-02  -> 19 rows
# Data added for: 2022-08-03  -> 19 rows
# Data added for: 2022-08-04  -> 19 rows
# Data added for: 2022-08-05  -> 19 rows
# Data added for: 2022-08-06  -> 19 rows
# Data added for: 2022-08-07  -> 19 rows
# Data added for: 2022-08-08  -> 19 rows
# Data added for: 2022-08-09  -> 19 rows
# Data added for: 2022-08-10  -> 19 rows
# Data added for: 2022-08-11  -> 19 rows
# Data added for: 2022-08-12  -> 19 rows
# Data added for: 2022-08-13  -> 19 rows
# Data added for: 2022-08-14  -> 19 rows
# Data added for: 2022-08-15  -> 19 rows
# Data added for: 2022-08-16  -> 19 rows
# Data added for: 2022-08-17  -> 19 rows
# Data added for: 2022-08-18  -> 19 rows
# Data added for: 2022-08-19  -> 19 rows
# Data added for: 2022-08-20  -> 19 rows
# Data added for: 2022-08-21  -> 19 rows
# Data added for: 2022-08-22  -> 19 rows
# Data added for: 2022-08-23  -> 19 rows
# Data added for: 2022-08-24  -> 19 rows
# Data added for: 2022-08-25  -> 19 rows
# Data added for: 2022-08-26  -> 19 rows
# Data added for: 2022-08-27  -> 19 rows
# Data added for: 2022-08-28  -> 19 rows
# Data added for: 2022-08-29  -> 19 rows
# Data added for: 2022-08-30  -> 19 rows
# Data added for: 2022-08-31  -> 19 rows
# Data added for: 2022-09-01  -> 19 rows
# Data added for: 2022-09-02  -> 19 rows
# Data added for: 2022-09-03  -> 19 rows
# Data added for: 2022-09-04  -> 19 rows
# Data added for: 2022-09-05  -> 19 rows
# Data added for: 2022-09-06  -> 19 rows
# Data added for: 2022-09-07  -> 19 rows
# Data added for: 2022-09-08  -> 19 rows
# Data added for: 2022-09-09  -> 19 rows
# Data added for: 2022-09-10  -> 19 rows
# Data added for: 2022-09-11  -> 19 rows
# Data added for: 2022-09-12  -> 19 rows
# Data added for: 2022-09-13  -> 19 rows
# Data added for: 2022-09-14  -> 19 rows
# Data added for: 2022-09-15  -> 19 rows
# Data added for: 2022-09-16  -> 19 rows
# Data added for: 2022-09-17  -> 19 rows
# Data added for: 2022-09-18  -> 19 rows
# Data added for: 2022-09-19  -> 19 rows
# Data added for: 2022-09-20  -> 19 rows
# Data added for: 2022-09-21  -> 19 rows
# Data added for: 2022-09-22  -> 19 rows
# Data added for: 2022-09-23  -> 19 rows
# Data added for: 2022-09-24  -> 19 rows
# Data added for: 2022-09-25  -> 19 rows
# Data added for: 2022-09-26  -> 19 rows
# Data added for: 2022-09-27  -> 19 rows
# Data added for: 2022-09-28  -> 19 rows
# Data added for: 2022-09-29  -> 19 rows
# Data added for: 2022-09-30  -> 19 rows
# Data added for: 2022-10-01  -> 19 rows
# Data added for: 2022-10-02  -> 19 rows
# Data added for: 2022-10-03  -> 19 rows
# Data added for: 2022-10-04  -> 19 rows
# Data added for: 2022-10-05  -> 19 rows
# Data added for: 2022-10-06  -> 19 rows
# Data added for: 2022-10-07  -> 19 rows
# Data added for: 2022-10-08  -> 19 rows
# Data added for: 2022-10-09  -> 19 rows
# Data added for: 2022-10-10  -> 19 rows
# Data added for: 2022-10-11  -> 19 rows
# Data added for: 2022-10-12  -> 19 rows
# Data added for: 2022-10-13  -> 19 rows
# Data added for: 2022-10-14  -> 19 rows
# Data added for: 2022-10-15  -> 19 rows
# Data added for: 2022-10-16  -> 19 rows
# Data added for: 2022-10-17  -> 19 rows
# Data added for: 2022-10-18  -> 19 rows
# Data added for: 2022-10-19  -> 19 rows
# Data added for: 2022-10-20  -> 19 rows
# Data added for: 2022-10-21  -> 19 rows
# Data added for: 2022-10-22  -> 19 rows
# Data added for: 2022-10-23  -> 19 rows
# Data added for: 2022-10-24  -> 19 rows
# Data added for: 2022-10-25  -> 19 rows
# Data added for: 2022-10-26  -> 19 rows
# Data added for: 2022-10-27  -> 19 rows
# Data added for: 2022-10-28  -> 19 rows
# Data added for: 2022-10-29  -> 19 rows
# Data added for: 2022-10-30  -> 19 rows
# Data added for: 2022-10-31  -> 19 rows
# Data added for: 2022-11-01  -> 19 rows
# Data added for: 2022-11-02  -> 19 rows
# Data added for: 2022-11-03  -> 19 rows
# Data added for: 2022-11-04  -> 19 rows
# Data added for: 2022-11-05  -> 19 rows
# Data added for: 2022-11-06  -> 19 rows
# Data added for: 2022-11-07  -> 19 rows
# Data added for: 2022-11-08  -> 19 rows
# Data added for: 2022-11-09  -> 19 rows
# Data added for: 2022-11-10  -> 19 rows
# Data added for: 2022-11-11  -> 19 rows
# Data added for: 2022-11-12  -> 19 rows
# Data added for: 2022-11-13  -> 19 rows
# Data added for: 2022-11-14  -> 19 rows
# Data added for: 2022-11-15  -> 19 rows
# Data added for: 2022-11-16  -> 19 rows
# Data added for: 2022-11-17  -> 19 rows
# Data added for: 2022-11-18  -> 19 rows
# Data added for: 2022-11-19  -> 19 rows
# Data added for: 2022-11-20  -> 19 rows
# Data added for: 2022-11-21  -> 19 rows
# Data added for: 2022-11-22  -> 19 rows
# Data added for: 2022-11-23  -> 19 rows
# Data added for: 2022-11-24  -> 19 rows
# Data added for: 2022-11-25  -> 19 rows
# Data added for: 2022-11-26  -> 19 rows
# Data added for: 2022-11-27  -> 19 rows
# Data added for: 2022-11-28  -> 19 rows
# Data added for: 2022-11-29  -> 19 rows
# Data added for: 2022-11-30  -> 19 rows
# Data added for: 2022-12-01  -> 19 rows
# Data added for: 2022-12-02  -> 19 rows
# Data added for: 2022-12-03  -> 19 rows
# Data added for: 2022-12-04  -> 19 rows
# Data added for: 2022-12-05  -> 19 rows
# Data added for: 2022-12-06  -> 19 rows
# Data added for: 2022-12-07  -> 19 rows
# Data added for: 2022-12-08  -> 19 rows
# Data added for: 2022-12-09  -> 19 rows
# Data added for: 2022-12-10  -> 19 rows
# Data added for: 2022-12-11  -> 19 rows
# Data added for: 2022-12-12  -> 19 rows
# Data added for: 2022-12-13  -> 19 rows
# Data added for: 2022-12-14  -> 19 rows
# Data added for: 2022-12-15  -> 19 rows
# Data added for: 2022-12-16  -> 19 rows
# Data added for: 2022-12-17  -> 19 rows
# Data added for: 2022-12-18  -> 19 rows
# Data added for: 2022-12-19  -> 19 rows
# Data added for: 2022-12-20  -> 19 rows
# Data added for: 2022-12-21  -> 19 rows
# Data added for: 2022-12-22  -> 19 rows
# Data added for: 2022-12-23  -> 19 rows
# Data added for: 2022-12-24  -> 19 rows
# Data added for: 2022-12-25  -> 19 rows
# Data added for: 2022-12-26  -> 19 rows
# Data added for: 2022-12-27  -> 19 rows
# Data added for: 2022-12-28  -> 19 rows
# Data added for: 2022-12-29  -> 19 rows
# Data added for: 2022-12-30  -> 19 rows
# Data added for: 2022-12-31  -> 19 rows
# Data added for: 2023-01-01  -> 19 rows
# Data added for: 2023-01-02  -> 19 rows
# Data added for: 2023-01-03  -> 19 rows
# Data added for: 2023-01-04  -> 19 rows
# Data added for: 2023-01-05  -> 19 rows
# Data added for: 2023-01-06  -> 19 rows
# Data added for: 2023-01-07  -> 19 rows
# Data added for: 2023-01-08  -> 19 rows
# Data added for: 2023-01-09  -> 19 rows
# Data added for: 2023-01-10  -> 19 rows
# Data added for: 2023-01-11  -> 19 rows
# Data added for: 2023-01-12  -> 19 rows
# Data added for: 2023-01-13  -> 19 rows
# Data added for: 2023-01-14  -> 19 rows
# Data added for: 2023-01-15  -> 19 rows
# Data added for: 2023-01-16  -> 19 rows
# Data added for: 2023-01-17  -> 19 rows
# Data added for: 2023-01-18  -> 19 rows
# Data added for: 2023-01-19  -> 19 rows
# Data added for: 2023-01-20  -> 19 rows
# Data added for: 2023-01-21  -> 19 rows
# Data added for: 2023-01-22  -> 19 rows
# Data added for: 2023-01-23  -> 19 rows
# Data added for: 2023-01-24  -> 19 rows
# Data added for: 2023-01-25  -> 19 rows
# Data added for: 2023-01-26  -> 19 rows
# Data added for: 2023-01-27  -> 19 rows
# Data added for: 2023-01-28  -> 19 rows
# Data added for: 2023-01-29  -> 19 rows
# Data added for: 2023-01-30  -> 19 rows
# Data added for: 2023-01-31  -> 19 rows
# Data added for: 2023-02-01  -> 19 rows
# Data added for: 2023-02-02  -> 19 rows
# Data added for: 2023-02-03  -> 19 rows
# Data added for: 2023-02-04  -> 19 rows
# Data added for: 2023-02-05  -> 19 rows
# Data added for: 2023-02-06  -> 19 rows
# Data added for: 2023-02-07  -> 19 rows
# Data added for: 2023-02-08  -> 19 rows
# Data added for: 2023-02-09  -> 19 rows
# Data added for: 2023-02-10  -> 19 rows
# Data added for: 2023-02-11  -> 19 rows
# Data added for: 2023-02-12  -> 19 rows
# Data added for: 2023-02-13  -> 19 rows
# Data added for: 2023-02-14  -> 19 rows
# Data added for: 2023-02-15  -> 19 rows
# Data added for: 2023-02-16  -> 19 rows
# Data added for: 2023-02-17  -> 19 rows
# Data added for: 2023-02-18  -> 19 rows
# Data added for: 2023-02-19  -> 19 rows
# Data added for: 2023-02-20  -> 19 rows
# Data added for: 2023-02-21  -> 19 rows
# Data added for: 2023-02-22  -> 19 rows
# Data added for: 2023-02-23  -> 19 rows
# Data added for: 2023-02-24  -> 19 rows
# Data added for: 2023-02-25  -> 19 rows
# Data added for: 2023-02-26  -> 19 rows
# Data added for: 2023-02-27  -> 19 rows
# Data added for: 2023-02-28  -> 19 rows
# Data added for: 2023-03-01  -> 19 rows
# Data added for: 2023-03-02  -> 19 rows
# Data added for: 2023-03-03  -> 19 rows
# Data added for: 2023-03-04  -> 19 rows
# Data added for: 2023-03-05  -> 19 rows
# Data added for: 2023-03-06  -> 19 rows
# Data added for: 2023-03-07  -> 19 rows
# Data added for: 2023-03-08  -> 19 rows
# Data added for: 2023-03-09  -> 19 rows
# Data added for: 2023-03-10  -> 19 rows
# Data added for: 2023-03-11  -> 19 rows
# Data added for: 2023-03-12  -> 19 rows
# Data added for: 2023-03-13  -> 19 rows
# Data added for: 2023-03-14  -> 19 rows
# Data added for: 2023-03-15  -> 19 rows
# Data added for: 2023-03-16  -> 19 rows
# Data added for: 2023-03-17  -> 19 rows
# Data added for: 2023-03-18  -> 19 rows
# Data added for: 2023-03-19  -> 19 rows
# Data added for: 2023-03-20  -> 19 rows
# Data added for: 2023-03-21  -> 19 rows
# Data added for: 2023-03-22  -> 19 rows
# Data added for: 2023-03-23  -> 19 rows
# Data added for: 2023-03-24  -> 19 rows
# Data added for: 2023-03-25  -> 19 rows
# Data added for: 2023-03-26  -> 19 rows
# Data added for: 2023-03-27  -> 19 rows
# Data added for: 2023-03-28  -> 19 rows
# Data added for: 2023-03-29  -> 19 rows
# Data added for: 2023-03-30  -> 19 rows
# Data added for: 2023-03-31  -> 19 rows
# Data added for: 2023-04-01  -> 19 rows
# Data added for: 2023-04-02  -> 19 rows
# Data added for: 2023-04-03  -> 19 rows
# Data added for: 2023-04-04  -> 19 rows
# Data added for: 2023-04-05  -> 19 rows
# Data added for: 2023-04-06  -> 19 rows
# Data added for: 2023-04-07  -> 19 rows
# Data added for: 2023-04-08  -> 19 rows
# Data added for: 2023-04-09  -> 19 rows
# Data added for: 2023-04-10  -> 19 rows
# Data added for: 2023-04-11  -> 19 rows
# Data added for: 2023-04-12  -> 19 rows
# Data added for: 2023-04-13  -> 19 rows
# Data added for: 2023-04-14  -> 19 rows
# Data added for: 2023-04-15  -> 19 rows
# Data added for: 2023-04-16  -> 19 rows
# Data added for: 2023-04-17  -> 19 rows
# Data added for: 2023-04-18  -> 19 rows
# Data added for: 2023-04-19  -> 19 rows
# Data added for: 2023-04-20  -> 19 rows
# Data added for: 2023-04-21  -> 19 rows
# Data added for: 2023-04-22  -> 19 rows
# Data added for: 2023-04-23  -> 19 rows
# Data added for: 2023-04-24  -> 19 rows
# Data added for: 2023-04-25  -> 19 rows
# Data added for: 2023-04-26  -> 19 rows
# Data added for: 2023-04-27  -> 19 rows
# Data added for: 2023-04-28  -> 19 rows
# Data added for: 2023-04-29  -> 19 rows
# Data added for: 2023-04-30  -> 19 rows
# Data added for: 2023-05-01  -> 19 rows
# Data added for: 2023-05-02  -> 19 rows
# Data added for: 2023-05-03  -> 19 rows
# Data added for: 2023-05-04  -> 19 rows
# Data added for: 2023-05-05  -> 19 rows
# Data added for: 2023-05-06  -> 19 rows
# Data added for: 2023-05-07  -> 19 rows
# Data added for: 2023-05-08  -> 19 rows
# Data added for: 2023-05-09  -> 19 rows
# Data added for: 2023-05-10  -> 19 rows
# Data added for: 2023-05-11  -> 19 rows
# Data added for: 2023-05-12  -> 19 rows
# Data added for: 2023-05-13  -> 19 rows
# Data added for: 2023-05-14  -> 19 rows
# Data added for: 2023-05-15  -> 19 rows
# Data added for: 2023-05-16  -> 19 rows
# Data added for: 2023-05-17  -> 19 rows
# Data added for: 2023-05-18  -> 19 rows
# Data added for: 2023-05-19  -> 19 rows
# Data added for: 2023-05-20  -> 19 rows
# Data added for: 2023-05-21  -> 19 rows
# Data added for: 2023-05-22  -> 19 rows
# Data added for: 2023-05-23  -> 19 rows
# Data added for: 2023-05-24  -> 19 rows
# Data added for: 2023-05-25  -> 19 rows
# Data added for: 2023-05-26  -> 19 rows
# Data added for: 2023-05-27  -> 19 rows
# Data added for: 2023-05-28  -> 19 rows
# Data added for: 2023-05-29  -> 19 rows
# Data added for: 2023-05-30  -> 19 rows
# Data added for: 2023-05-31  -> 19 rows
# Data added for: 2023-06-01  -> 19 rows
# Data added for: 2023-06-02  -> 19 rows
# Data added for: 2023-06-03  -> 19 rows
# Data added for: 2023-06-04  -> 19 rows
# Data added for: 2023-06-05  -> 19 rows
# Data added for: 2023-06-06  -> 19 rows
# Data added for: 2023-06-07  -> 19 rows
# Data added for: 2023-06-08  -> 19 rows
# Data added for: 2023-06-09  -> 19 rows
# Data added for: 2023-06-10  -> 19 rows
# Data added for: 2023-06-11  -> 19 rows
# Data added for: 2023-06-12  -> 19 rows
# Data added for: 2023-06-13  -> 19 rows
# Data added for: 2023-06-14  -> 19 rows
# Data added for: 2023-06-15  -> 19 rows
# Data added for: 2023-06-16  -> 19 rows
# Data added for: 2023-06-17  -> 19 rows
# Data added for: 2023-06-18  -> 19 rows
# Data added for: 2023-06-19  -> 19 rows
# Data added for: 2023-06-20  -> 19 rows
# Data added for: 2023-06-21  -> 19 rows
# Data added for: 2023-06-22  -> 19 rows
# Data added for: 2023-06-23  -> 19 rows
# Data added for: 2023-06-24  -> 19 rows
# Data added for: 2023-06-25  -> 19 rows
# Data added for: 2023-06-26  -> 19 rows
# Data added for: 2023-06-27  -> 19 rows
# Data added for: 2023-06-28  -> 19 rows
# Data added for: 2023-06-29  -> 19 rows
# Data added for: 2023-06-30  -> 19 rows
# Data added for: 2023-07-01  -> 19 rows
# Data added for: 2023-07-02  -> 19 rows
# Data added for: 2023-07-03  -> 19 rows
# Data added for: 2023-07-04  -> 19 rows
# Data added for: 2023-07-05  -> 19 rows
# Data added for: 2023-07-06  -> 19 rows
# Data added for: 2023-07-07  -> 19 rows
# Data added for: 2023-07-08  -> 19 rows
# Data added for: 2023-07-09  -> 19 rows
# Data added for: 2023-07-10  -> 19 rows
# Data added for: 2023-07-11  -> 19 rows
# Data added for: 2023-07-12  -> 19 rows
# Data added for: 2023-07-13  -> 19 rows
# Data added for: 2023-07-14  -> 19 rows
# Data added for: 2023-07-15  -> 19 rows
# Data added for: 2023-07-16  -> 19 rows
# Data added for: 2023-07-17  -> 19 rows
# Data added for: 2023-07-18  -> 19 rows
# Data added for: 2023-07-19  -> 19 rows
# Data added for: 2023-07-20  -> 19 rows
# Data added for: 2023-07-21  -> 19 rows
# Data added for: 2023-07-22  -> 19 rows
# Data added for: 2023-07-23  -> 19 rows
# Data added for: 2023-07-24  -> 19 rows
# Data added for: 2023-07-25  -> 19 rows
# Data added for: 2023-07-26  -> 19 rows
# Data added for: 2023-07-27  -> 19 rows
# Data added for: 2023-07-28  -> 19 rows
# Data added for: 2023-07-29  -> 19 rows
# Data added for: 2023-07-30  -> 19 rows
# Data added for: 2023-07-31  -> 19 rows
# Data added for: 2023-08-01  -> 19 rows
# Data added for: 2023-08-02  -> 19 rows
# Data added for: 2023-08-03  -> 19 rows
# Data added for: 2023-08-04  -> 19 rows
# Data added for: 2023-08-05  -> 19 rows
# Data added for: 2023-08-06  -> 19 rows
# Data added for: 2023-08-07  -> 19 rows
# Data added for: 2023-08-08  -> 19 rows
# Data added for: 2023-08-09  -> 19 rows
# Data added for: 2023-08-10  -> 19 rows
# Data added for: 2023-08-11  -> 19 rows
# Data added for: 2023-08-12  -> 19 rows
# Data added for: 2023-08-13  -> 19 rows
# Data added for: 2023-08-14  -> 19 rows
# Data added for: 2023-08-15  -> 19 rows
# Data added for: 2023-08-16  -> 19 rows
# Data added for: 2023-08-17  -> 19 rows
# Data added for: 2023-08-18  -> 19 rows
# Data added for: 2023-08-19  -> 19 rows
# Data added for: 2023-08-20  -> 19 rows
# Data added for: 2023-08-21  -> 19 rows
# Data added for: 2023-08-22  -> 19 rows
# Data added for: 2023-08-23  -> 19 rows
# Data added for: 2023-08-24  -> 19 rows
# Data added for: 2023-08-25  -> 19 rows
# Data added for: 2023-08-26  -> 19 rows
# Data added for: 2023-08-27  -> 19 rows
# Data added for: 2023-08-28  -> 19 rows
# Data added for: 2023-08-29  -> 19 rows
# Data added for: 2023-08-30  -> 19 rows
# Data added for: 2023-08-31  -> 19 rows
# Data added for: 2023-09-01  -> 19 rows
# Data added for: 2023-09-02  -> 19 rows
# Data added for: 2023-09-03  -> 19 rows
# Data added for: 2023-09-04  -> 19 rows
# Data added for: 2023-09-05  -> 19 rows
# Data added for: 2023-09-06  -> 19 rows
# Data added for: 2023-09-07  -> 19 rows
# Data added for: 2023-09-08  -> 19 rows
# Data added for: 2023-09-09  -> 19 rows
# Data added for: 2023-09-10  -> 19 rows
# Data added for: 2023-09-11  -> 19 rows
# Data added for: 2023-09-12  -> 19 rows
# Data added for: 2023-09-13  -> 19 rows
# Data added for: 2023-09-14  -> 19 rows
# Data added for: 2023-09-15  -> 19 rows
# Data added for: 2023-09-16  -> 19 rows
# Data added for: 2023-09-17  -> 19 rows
# Data added for: 2023-09-18  -> 19 rows
# Data added for: 2023-09-19  -> 19 rows
# Data added for: 2023-09-20  -> 19 rows
# Data added for: 2023-09-21  -> 19 rows
# Data added for: 2023-09-22  -> 19 rows
# Data added for: 2023-09-23  -> 19 rows
# Data added for: 2023-09-24  -> 19 rows
# Data added for: 2023-09-25  -> 19 rows
# Data added for: 2023-09-26  -> 19 rows
# Data added for: 2023-09-27  -> 19 rows
# Data added for: 2023-09-28  -> 19 rows
# Data added for: 2023-09-29  -> 19 rows
# Data added for: 2023-09-30  -> 19 rows
# Data added for: 2023-10-01  -> 19 rows
# Data added for: 2023-10-02  -> 19 rows
# Data added for: 2023-10-03  -> 19 rows
# Data added for: 2023-10-04  -> 19 rows
# Data added for: 2023-10-05  -> 19 rows
# Data added for: 2023-10-06  -> 19 rows
# Data added for: 2023-10-07  -> 19 rows
# Data added for: 2023-10-08  -> 19 rows
# Data added for: 2023-10-09  -> 19 rows
# Data added for: 2023-10-10  -> 19 rows
# Data added for: 2023-10-11  -> 19 rows
# Data added for: 2023-10-12  -> 19 rows
# Data added for: 2023-10-13  -> 19 rows
# Data added for: 2023-10-14  -> 19 rows
# Data added for: 2023-10-15  -> 19 rows
# Data added for: 2023-10-16  -> 19 rows
# Data added for: 2023-10-17  -> 19 rows
# Data added for: 2023-10-18  -> 19 rows
# Data added for: 2023-10-19  -> 19 rows
# Data added for: 2023-10-20  -> 19 rows
# Data added for: 2023-10-21  -> 19 rows
# Data added for: 2023-10-22  -> 19 rows
# Data added for: 2023-10-23  -> 19 rows
# Data added for: 2023-10-24  -> 19 rows
# Data added for: 2023-10-25  -> 19 rows
# Data added for: 2023-10-26  -> 19 rows
# Data added for: 2023-10-27  -> 19 rows
# Data added for: 2023-10-28  -> 19 rows
# Data added for: 2023-10-29  -> 19 rows
# Data added for: 2023-10-30  -> 19 rows
# Data added for: 2023-10-31  -> 19 rows
# Data added for: 2023-11-01  -> 19 rows
# Data added for: 2023-11-02  -> 19 rows
# Data added for: 2023-11-03  -> 19 rows
# Data added for: 2023-11-04  -> 19 rows
# Data added for: 2023-11-05  -> 19 rows
# Data added for: 2023-11-06  -> 19 rows
# Data added for: 2023-11-07  -> 19 rows
# Data added for: 2023-11-08  -> 19 rows
# Data added for: 2023-11-09  -> 19 rows
# Data added for: 2023-11-10  -> 19 rows
# Data added for: 2023-11-11  -> 19 rows
# Data added for: 2023-11-12  -> 19 rows
# Data added for: 2023-11-13  -> 19 rows
# Data added for: 2023-11-14  -> 19 rows
# Data added for: 2023-11-15  -> 19 rows
# Data added for: 2023-11-16  -> 19 rows
# Data added for: 2023-11-17  -> 19 rows
# Data added for: 2023-11-18  -> 19 rows
# Data added for: 2023-11-19  -> 19 rows
# Data added for: 2023-11-20  -> 19 rows
# Data added for: 2023-11-21  -> 19 rows
# Data added for: 2023-11-22  -> 19 rows
# Data added for: 2023-11-23  -> 19 rows
# Data added for: 2023-11-24  -> 19 rows
# Data added for: 2023-11-25  -> 19 rows
# Data added for: 2023-11-26  -> 19 rows
# Data added for: 2023-11-27  -> 19 rows
# Data added for: 2023-11-28  -> 19 rows
# Data added for: 2023-11-29  -> 19 rows
# Data added for: 2023-11-30  -> 19 rows
# Data added for: 2023-12-01  -> 19 rows
# Data added for: 2023-12-02  -> 19 rows
# Data added for: 2023-12-03  -> 19 rows
# Data added for: 2023-12-04  -> 19 rows
# Data added for: 2023-12-05  -> 19 rows
# Data added for: 2023-12-06  -> 19 rows
# Data added for: 2023-12-07  -> 19 rows
# Data added for: 2023-12-08  -> 19 rows
# Data added for: 2023-12-09  -> 19 rows
# Data added for: 2023-12-10  -> 19 rows
# Data added for: 2023-12-11  -> 19 rows
# Data added for: 2023-12-12  -> 19 rows
# Data added for: 2023-12-13  -> 19 rows
# Data added for: 2023-12-14  -> 19 rows
# Data added for: 2023-12-15  -> 19 rows
# Data added for: 2023-12-16  -> 19 rows
# Data added for: 2023-12-17  -> 19 rows
# Data added for: 2023-12-18  -> 19 rows
# Data added for: 2023-12-19  -> 19 rows
# Data added for: 2023-12-20  -> 19 rows
# Data added for: 2023-12-21  -> 19 rows
# Data added for: 2023-12-22  -> 19 rows
# Data added for: 2023-12-23  -> 19 rows
# Data added for: 2023-12-24  -> 19 rows
# Data added for: 2023-12-25  -> 19 rows
# Data added for: 2023-12-26  -> 19 rows
# Data added for: 2023-12-27  -> 19 rows
# Data added for: 2023-12-28  -> 19 rows
# Data added for: 2023-12-29  -> 19 rows
# Data added for: 2023-12-30  -> 19 rows
# Data added for: 2023-12-31  -> 19 rows
# Data added for: 2024-01-01  -> 19 rows
# Data added for: 2024-01-02  -> 19 rows
# Data added for: 2024-01-03  -> 19 rows
# Data added for: 2024-01-04  -> 19 rows
# Data added for: 2024-01-05  -> 19 rows
# Data added for: 2024-01-06  -> 19 rows
# Data added for: 2024-01-07  -> 19 rows
# Data added for: 2024-01-08  -> 19 rows
# Data added for: 2024-01-09  -> 19 rows
# Data added for: 2024-01-10  -> 19 rows
# Data added for: 2024-01-11  -> 19 rows
# Data added for: 2024-01-12  -> 19 rows
# Data added for: 2024-01-13  -> 19 rows
# Data added for: 2024-01-14  -> 19 rows
# Data added for: 2024-01-15  -> 19 rows
# Data added for: 2024-01-16  -> 19 rows
# Data added for: 2024-01-17  -> 19 rows
# Data added for: 2024-01-18  -> 19 rows
# Data added for: 2024-01-19  -> 19 rows
# Data added for: 2024-01-20  -> 19 rows
# Data added for: 2024-01-21  -> 19 rows
# Data added for: 2024-01-22  -> 19 rows
# Data added for: 2024-01-23  -> 19 rows
# Data added for: 2024-01-24  -> 19 rows
# Data added for: 2024-01-25  -> 19 rows
# Data added for: 2024-01-26  -> 19 rows
# Data added for: 2024-01-27  -> 19 rows
# Data added for: 2024-01-28  -> 19 rows
# Data added for: 2024-01-29  -> 19 rows
# Data added for: 2024-01-30  -> 19 rows
# Data added for: 2024-01-31  -> 19 rows
# Data added for: 2024-02-01  -> 19 rows
# Data added for: 2024-02-02  -> 19 rows
# Data added for: 2024-02-03  -> 19 rows
# Data added for: 2024-02-04  -> 19 rows
# Data added for: 2024-02-05  -> 19 rows
# Data added for: 2024-02-06  -> 19 rows
# Data added for: 2024-02-07  -> 19 rows
# Data added for: 2024-02-08  -> 19 rows
# Data added for: 2024-02-09  -> 19 rows
# Data added for: 2024-02-10  -> 19 rows
# Data added for: 2024-02-11  -> 19 rows
# Data added for: 2024-02-12  -> 19 rows
# Data added for: 2024-02-13  -> 19 rows
# Data added for: 2024-02-14  -> 19 rows
# Data added for: 2024-02-15  -> 19 rows
# Data added for: 2024-02-16  -> 19 rows
# Data added for: 2024-02-17  -> 19 rows
# Data added for: 2024-02-18  -> 19 rows
# Data added for: 2024-02-19  -> 19 rows
# Data added for: 2024-02-20  -> 19 rows
# Data added for: 2024-02-21  -> 19 rows
# Data added for: 2024-02-22  -> 19 rows
# Data added for: 2024-02-23  -> 19 rows
# Data added for: 2024-02-24  -> 19 rows
# Data added for: 2024-02-25  -> 19 rows
# Data added for: 2024-02-26  -> 19 rows
# Data added for: 2024-02-27  -> 19 rows
# Data added for: 2024-02-28  -> 19 rows
# Data added for: 2024-02-29  -> 19 rows
# Data added for: 2024-03-01  -> 19 rows
# Data added for: 2024-03-02  -> 19 rows
# Data added for: 2024-03-03  -> 19 rows
# Data added for: 2024-03-04  -> 19 rows
# Data added for: 2024-03-05  -> 19 rows
# Data added for: 2024-03-06  -> 19 rows
# Data added for: 2024-03-07  -> 19 rows
# Data added for: 2024-03-08  -> 19 rows
# Data added for: 2024-03-09  -> 19 rows
# Data added for: 2024-03-10  -> 19 rows
# Data added for: 2024-03-11  -> 19 rows
# Data added for: 2024-03-12  -> 19 rows
# Data added for: 2024-03-13  -> 19 rows
# Data added for: 2024-03-14  -> 19 rows
# Data added for: 2024-03-15  -> 19 rows
# Data added for: 2024-03-16  -> 19 rows
# Data added for: 2024-03-17  -> 19 rows
# Data added for: 2024-03-18  -> 19 rows
# Data added for: 2024-03-19  -> 19 rows
# Data added for: 2024-03-20  -> 19 rows
# Data added for: 2024-03-21  -> 19 rows
# Data added for: 2024-03-22  -> 19 rows
# Data added for: 2024-03-23  -> 19 rows
# Data added for: 2024-03-24  -> 19 rows
# Data added for: 2024-03-25  -> 19 rows
# Data added for: 2024-03-26  -> 19 rows
# Data added for: 2024-03-27  -> 19 rows
# Data added for: 2024-03-28  -> 19 rows
# Data added for: 2024-03-29  -> 19 rows
# Data added for: 2024-03-30  -> 19 rows
# Data added for: 2024-03-31  -> 19 rows
# Data added for: 2024-04-01  -> 19 rows
# Data added for: 2024-04-02  -> 19 rows
# Data added for: 2024-04-03  -> 19 rows
# Data added for: 2024-04-04  -> 19 rows
# Data added for: 2024-04-05  -> 19 rows
# Data added for: 2024-04-06  -> 19 rows
# Data added for: 2024-04-07  -> 19 rows
# Data added for: 2024-04-08  -> 19 rows
# Data added for: 2024-04-09  -> 19 rows
# Data added for: 2024-04-10  -> 19 rows
# Data added for: 2024-04-11  -> 19 rows
# Data added for: 2024-04-12  -> 19 rows
# Data added for: 2024-04-13  -> 19 rows
# Data added for: 2024-04-14  -> 19 rows
# Data added for: 2024-04-15  -> 19 rows
# Data added for: 2024-04-16  -> 19 rows
# Data added for: 2024-04-17  -> 19 rows
# Data added for: 2024-04-18  -> 19 rows
# Data added for: 2024-04-19  -> 19 rows
# Data added for: 2024-04-20  -> 19 rows
# Data added for: 2024-04-21  -> 19 rows
# Data added for: 2024-04-22  -> 19 rows
# Data added for: 2024-04-23  -> 19 rows
# Data added for: 2024-04-24  -> 19 rows
# Data added for: 2024-04-25  -> 19 rows
# Data added for: 2024-04-26  -> 19 rows
# Data added for: 2024-04-27  -> 19 rows
# Data added for: 2024-04-28  -> 19 rows
# Data added for: 2024-04-29  -> 19 rows
# Data added for: 2024-04-30  -> 19 rows
# Data added for: 2024-05-01  -> 19 rows
# Data added for: 2024-05-02  -> 19 rows
# Data added for: 2024-05-03  -> 19 rows
# Data added for: 2024-05-04  -> 19 rows
# Data added for: 2024-05-05  -> 19 rows
# Data added for: 2024-05-06  -> 19 rows
# Data added for: 2024-05-07  -> 19 rows
# Data added for: 2024-05-08  -> 19 rows
# Data added for: 2024-05-09  -> 19 rows
# Data added for: 2024-05-10  -> 19 rows
# Data added for: 2024-05-11  -> 19 rows
# Data added for: 2024-05-12  -> 19 rows
# Data added for: 2024-05-13  -> 19 rows
# Data added for: 2024-05-14  -> 19 rows
# Data added for: 2024-05-15  -> 19 rows
# Data added for: 2024-05-16  -> 19 rows
# Data added for: 2024-05-17  -> 19 rows
# Data added for: 2024-05-18  -> 19 rows
# Data added for: 2024-05-19  -> 19 rows
# Data added for: 2024-05-20  -> 19 rows
# Data added for: 2024-05-21  -> 19 rows
# Data added for: 2024-05-22  -> 19 rows
# Data added for: 2024-05-23  -> 19 rows
# Data added for: 2024-05-24  -> 19 rows
# Data added for: 2024-05-25  -> 19 rows
# Data added for: 2024-05-26  -> 19 rows
# Data added for: 2024-05-27  -> 19 rows
# Data added for: 2024-05-28  -> 19 rows
# Data added for: 2024-05-29  -> 19 rows
# Data added for: 2024-05-30  -> 19 rows
# Data added for: 2024-05-31  -> 19 rows
# Data added for: 2024-06-01  -> 19 rows
# Data added for: 2024-06-02  -> 19 rows
# Data added for: 2024-06-03  -> 19 rows
# Data added for: 2024-06-04  -> 19 rows
# Data added for: 2024-06-05  -> 19 rows
# Data added for: 2024-06-06  -> 19 rows
# Data added for: 2024-06-07  -> 19 rows
# Data added for: 2024-06-08  -> 19 rows
# Data added for: 2024-06-09  -> 19 rows
# Data added for: 2024-06-10  -> 19 rows
# Data added for: 2024-06-11  -> 19 rows
# Data added for: 2024-06-12  -> 19 rows
# Data added for: 2024-06-13  -> 19 rows
# Data added for: 2024-06-14  -> 19 rows
# Data added for: 2024-06-15  -> 19 rows
# Data added for: 2024-06-16  -> 19 rows
# Data added for: 2024-06-17  -> 19 rows
# Data added for: 2024-06-18  -> 19 rows
# Data added for: 2024-06-19  -> 19 rows
# Data added for: 2024-06-20  -> 19 rows
# Data added for: 2024-06-21  -> 19 rows
# Data added for: 2024-06-22  -> 19 rows
# Data added for: 2024-06-23  -> 19 rows
# Data added for: 2024-06-24  -> 19 rows
# Data added for: 2024-06-25  -> 19 rows
# Data added for: 2024-06-26  -> 19 rows
# Data added for: 2024-06-27  -> 19 rows
# Data added for: 2024-06-28  -> 19 rows
# Data added for: 2024-06-29  -> 19 rows
# Data added for: 2024-06-30  -> 19 rows
# Data added for: 2024-07-01  -> 19 rows
# Data added for: 2024-07-02  -> 19 rows
# Data added for: 2024-07-03  -> 19 rows
# Data added for: 2024-07-04  -> 19 rows
# Data added for: 2024-07-05  -> 19 rows
# Data added for: 2024-07-06  -> 19 rows
# Data added for: 2024-07-07  -> 19 rows
# Data added for: 2024-07-08  -> 19 rows
# Data added for: 2024-07-09  -> 19 rows
# Data added for: 2024-07-10  -> 19 rows
# Data added for: 2024-07-11  -> 19 rows
# Data added for: 2024-07-12  -> 19 rows
# Data added for: 2024-07-13  -> 19 rows
# Data added for: 2024-07-14  -> 19 rows
# Data added for: 2024-07-15  -> 19 rows
# Data added for: 2024-07-16  -> 19 rows
# Data added for: 2024-07-17  -> 19 rows
# Data added for: 2024-07-18  -> 19 rows
# Data added for: 2024-07-19  -> 19 rows
# Data added for: 2024-07-20  -> 19 rows
# Data added for: 2024-07-21  -> 19 rows
# Data added for: 2024-07-22  -> 19 rows
# Data added for: 2024-07-23  -> 19 rows
# Data added for: 2024-07-24  -> 19 rows
# Data added for: 2024-07-25  -> 19 rows
# Data added for: 2024-07-26  -> 19 rows
# Data added for: 2024-07-27  -> 19 rows
# Data added for: 2024-07-28  -> 19 rows
# Data added for: 2024-07-29  -> 19 rows
# Data added for: 2024-07-30  -> 19 rows
# Data added for: 2024-07-31  -> 19 rows
# Data added for: 2024-08-01  -> 19 rows
# Data added for: 2024-08-02  -> 57 rows
# Data added for: 2024-08-03  -> 19 rows
# Data added for: 2024-08-04  -> 19 rows
# Data added for: 2024-08-05  -> 19 rows
# Data added for: 2024-08-06  -> 19 rows
# Data added for: 2024-08-07  -> 19 rows
# Data added for: 2024-08-08  -> 19 rows
# Data added for: 2024-08-09  -> 19 rows
# Data added for: 2024-08-10  -> 19 rows
# Data added for: 2024-08-11  -> 19 rows
# Data added for: 2024-08-12  -> 19 rows
# Data added for: 2024-08-13  -> 19 rows
# Data added for: 2024-08-14  -> 19 rows
# Data added for: 2024-08-15  -> 19 rows
# Data added for: 2024-08-16  -> 19 rows
# Data added for: 2024-08-17  -> 19 rows
# Data added for: 2024-08-18  -> 19 rows
# Data added for: 2024-08-19  -> 19 rows
# Data added for: 2024-08-20  -> 19 rows
# Data added for: 2024-08-21  -> 19 rows
# Data added for: 2024-08-22  -> 19 rows
# Data added for: 2024-08-23  -> 19 rows
# Data added for: 2024-08-24  -> 19 rows
# Data added for: 2024-08-25  -> 19 rows
# Data added for: 2024-08-26  -> 19 rows
# Data added for: 2024-08-27  -> 19 rows
# Data added for: 2024-08-28  -> 19 rows
# Data added for: 2024-08-29  -> 19 rows
# Data added for: 2024-08-30  -> 19 rows
# Data added for: 2024-08-31  -> 19 rows
# Data added for: 2024-09-01  -> 19 rows
# Data added for: 2024-09-02  -> 19 rows
# Data added for: 2024-09-03  -> 19 rows
# Data added for: 2024-09-04  -> 19 rows
# Data added for: 2024-09-05  -> 19 rows
# Data added for: 2024-09-06  -> 19 rows
# Data added for: 2024-09-07  -> 19 rows
# Data added for: 2024-09-08  -> 19 rows
# Data added for: 2024-09-09  -> 19 rows
# Data added for: 2024-09-10  -> 19 rows
# Data added for: 2024-09-11  -> 19 rows
# Data added for: 2024-09-12  -> 19 rows
# Data added for: 2024-09-13  -> 19 rows
# Data added for: 2024-09-14  -> 19 rows
# Data added for: 2024-09-15  -> 19 rows
# Data added for: 2024-09-16  -> 19 rows
# Data added for: 2024-09-17  -> 19 rows
# Data added for: 2024-09-18  -> 19 rows
# Data added for: 2024-09-19  -> 19 rows
# Data added for: 2024-09-20  -> 19 rows
# Data added for: 2024-09-21  -> 19 rows
# Data added for: 2024-09-22  -> 19 rows
# Data added for: 2024-09-23  -> 19 rows
# Data added for: 2024-09-24  -> 19 rows
# Data added for: 2024-09-25  -> 19 rows
# Data added for: 2024-09-26  -> 19 rows
# Data added for: 2024-09-27  -> 19 rows
# Data added for: 2024-09-28  -> 19 rows
# Data added for: 2024-09-29  -> 19 rows
# Data added for: 2024-09-30  -> 19 rows
# Data added for: 2024-10-01  -> 19 rows
# Data added for: 2024-10-02  -> 19 rows
# Data added for: 2024-10-03  -> 19 rows
# Data added for: 2024-10-04  -> 19 rows
# Data added for: 2024-10-05  -> 19 rows
# Data added for: 2024-10-06  -> 19 rows
# Data added for: 2024-10-07  -> 19 rows
# Data added for: 2024-10-08  -> 19 rows
# Data added for: 2024-10-09  -> 19 rows
# Data added for: 2024-10-10  -> 19 rows
# Data added for: 2024-10-11  -> 19 rows
# Data added for: 2024-10-12  -> 19 rows
# Data added for: 2024-10-13  -> 19 rows
# Data added for: 2024-10-14  -> 19 rows
# Data added for: 2024-10-15  -> 19 rows
# Data added for: 2024-10-16  -> 19 rows
# Data added for: 2024-10-17  -> 19 rows
# Data added for: 2024-10-18  -> 19 rows
# Data added for: 2024-10-19  -> 19 rows
# Data added for: 2024-10-20  -> 19 rows
# Data added for: 2024-10-21  -> 19 rows
# Data added for: 2024-10-22  -> 19 rows
# Data added for: 2024-10-23  -> 19 rows
# Data added for: 2024-10-24  -> 19 rows
# Data added for: 2024-10-25  -> 19 rows
# Data added for: 2024-10-26  -> 19 rows
# Data added for: 2024-10-27  -> 19 rows
# Data added for: 2024-10-28  -> 19 rows
# Data added for: 2024-10-29  -> 19 rows
# Data added for: 2024-10-30  -> 19 rows
# Data added for: 2024-10-31  -> 19 rows
# Data added for: 2024-11-01  -> 19 rows
# Data added for: 2024-11-02  -> 19 rows
# Data added for: 2024-11-03  -> 19 rows
# Data added for: 2024-11-04  -> 19 rows
# Data added for: 2024-11-05  -> 19 rows
# Data added for: 2024-11-06  -> 19 rows
# Data added for: 2024-11-07  -> 19 rows
# Data added for: 2024-11-08  -> 19 rows
# Data added for: 2024-11-09  -> 19 rows
# Data added for: 2024-11-10  -> 19 rows
# Data added for: 2024-11-11  -> 19 rows
# Data added for: 2024-11-12  -> 19 rows
# Data added for: 2024-11-13  -> 19 rows
# Data added for: 2024-11-14  -> 19 rows
# Data added for: 2024-11-15  -> 19 rows
# Data added for: 2024-11-16  -> 19 rows
# Data added for: 2024-11-17  -> 19 rows
# Data added for: 2024-11-18  -> 19 rows
# Data added for: 2024-11-19  -> 19 rows
# Data added for: 2024-11-20  -> 19 rows
# Data added for: 2024-11-21  -> 19 rows
# Data added for: 2024-11-22  -> 19 rows
# Data added for: 2024-11-23  -> 19 rows
# Data added for: 2024-11-24  -> 19 rows
# Data added for: 2024-11-25  -> 19 rows
# Data added for: 2024-11-26  -> 19 rows
# Data added for: 2024-11-27  -> 19 rows
# Data added for: 2024-11-28  -> 19 rows
# Data added for: 2024-11-29  -> 19 rows
# Data added for: 2024-11-30  -> 19 rows
# Data added for: 2024-12-01  -> 19 rows
# Data added for: 2024-12-02  -> 19 rows
# Data added for: 2024-12-03  -> 19 rows
# Data added for: 2024-12-04  -> 19 rows
# Data added for: 2024-12-05  -> 19 rows
# Data added for: 2024-12-06  -> 19 rows
# Data added for: 2024-12-07  -> 19 rows
# Data added for: 2024-12-08  -> 19 rows
# Data added for: 2024-12-09  -> 19 rows
# Data added for: 2024-12-10  -> 19 rows
# Data added for: 2024-12-11  -> 19 rows
# Data added for: 2024-12-12  -> 19 rows
# Data added for: 2024-12-13  -> 19 rows
# Data added for: 2024-12-14  -> 19 rows
# Data added for: 2024-12-15  -> 19 rows
# Data added for: 2024-12-16  -> 19 rows
# Data added for: 2024-12-17  -> 19 rows
# Data added for: 2024-12-18  -> 19 rows
# Data added for: 2024-12-19  -> 19 rows
# Data added for: 2024-12-20  -> 19 rows
# Data added for: 2024-12-21  -> 19 rows
# Data added for: 2024-12-22  -> 19 rows
# Data added for: 2024-12-23  -> 19 rows
# Data added for: 2024-12-24  -> 19 rows
# Data added for: 2024-12-25  -> 19 rows
# Data added for: 2024-12-26  -> 19 rows
# Data added for: 2024-12-27  -> 19 rows
# Data added for: 2024-12-28  -> 19 rows
# Data added for: 2024-12-29  -> 19 rows
# Data added for: 2024-12-30  -> 19 rows
# Data added for: 2024-12-31  -> 19 rows
# Data added for: 2025-01-01  -> 19 rows
# Data added for: 2025-01-02  -> 19 rows
# Data added for: 2025-01-03  -> 19 rows
# Data added for: 2025-01-04  -> 19 rows
# Data added for: 2025-01-05  -> 19 rows
# Data added for: 2025-01-06  -> 19 rows
# Data added for: 2025-01-07  -> 19 rows
# Data added for: 2025-01-08  -> 19 rows
# Data added for: 2025-01-09  -> 19 rows
# Data added for: 2025-01-10  -> 19 rows
# Data added for: 2025-01-11  -> 19 rows
# Data added for: 2025-01-12  -> 19 rows
# Data added for: 2025-01-13  -> 19 rows
# Data added for: 2025-01-14  -> 19 rows
# Data added for: 2025-01-15  -> 19 rows
# Data added for: 2025-01-16  -> 19 rows
# Data added for: 2025-01-17  -> 19 rows
# Data added for: 2025-01-18  -> 19 rows
# Data added for: 2025-01-19  -> 19 rows
# Data added for: 2025-01-20  -> 19 rows
# Data added for: 2025-01-21  -> 19 rows
# Data added for: 2025-01-22  -> 19 rows
# Data added for: 2025-01-23  -> 19 rows
# Data added for: 2025-01-24  -> 19 rows
# Data added for: 2025-01-25  -> 19 rows
# Data added for: 2025-01-26  -> 19 rows
# Data added for: 2025-01-27  -> 19 rows
# Data added for: 2025-01-28  -> 19 rows
# Data added for: 2025-01-29  -> 19 rows
# Data added for: 2025-01-30  -> 19 rows
# Data added for: 2025-01-31  -> 19 rows
# Data added for: 2025-02-01  -> 19 rows
# Data added for: 2025-02-02  -> 19 rows
# Data added for: 2025-02-03  -> 19 rows
# Data added for: 2025-02-04  -> 19 rows
# Data added for: 2025-02-05  -> 19 rows
# Data added for: 2025-02-06  -> 19 rows
# Data added for: 2025-02-07  -> 19 rows
# Data added for: 2025-02-08  -> 19 rows
# Data added for: 2025-02-09  -> 19 rows
# Data added for: 2025-02-10  -> 19 rows
# Data added for: 2025-02-11  -> 19 rows
# Data added for: 2025-02-12  -> 19 rows
# Data added for: 2025-02-13  -> 19 rows
# Data added for: 2025-02-14  -> 19 rows
# Data added for: 2025-02-15  -> 19 rows
# Data added for: 2025-02-16  -> 19 rows
# Data added for: 2025-02-17  -> 19 rows
# Data added for: 2025-02-18  -> 19 rows
# Data added for: 2025-02-19  -> 19 rows
# Data added for: 2025-02-20  -> 19 rows
# Data added for: 2025-02-21  -> 19 rows
# Data added for: 2025-02-22  -> 19 rows
# Data added for: 2025-02-23  -> 19 rows
# Data added for: 2025-02-24  -> 19 rows
# Data added for: 2025-02-25  -> 19 rows
# Data added for: 2025-02-26  -> 19 rows
# Data added for: 2025-02-27  -> 19 rows
# Data added for: 2025-02-28  -> 19 rows
# Data added for: 2025-03-01  -> 19 rows
# Data added for: 2025-03-02  -> 19 rows
# Data added for: 2025-03-03  -> 19 rows
# Data added for: 2025-03-04  -> 19 rows
# Data added for: 2025-03-05  -> 19 rows
# Data added for: 2025-03-06  -> 19 rows
# Data added for: 2025-03-07  -> 19 rows
# Data added for: 2025-03-08  -> 19 rows
# Data added for: 2025-03-09  -> 19 rows
# Data added for: 2025-03-10  -> 19 rows
# Data added for: 2025-03-11  -> 19 rows
# Data added for: 2025-03-12  -> 19 rows
# Data added for: 2025-03-13  -> 19 rows
# Data added for: 2025-03-14  -> 19 rows
# Data added for: 2025-03-15  -> 19 rows
# Data added for: 2025-03-16  -> 19 rows
# Data added for: 2025-03-17  -> 19 rows
# Data added for: 2025-03-18  -> 19 rows
# Data added for: 2025-03-19  -> 19 rows
# Data added for: 2025-03-20  -> 19 rows
# Data added for: 2025-03-21  -> 19 rows
# Data added for: 2025-03-22  -> 19 rows
# Data added for: 2025-03-23  -> 19 rows
# Data added for: 2025-03-24  -> 19 rows
# Data added for: 2025-03-25  -> 19 rows
# Data added for: 2025-03-26  -> 19 rows
# Data added for: 2025-03-27  -> 19 rows
# Data added for: 2025-03-28  -> 19 rows
# Data added for: 2025-03-29  -> 19 rows
# Data added for: 2025-03-30  -> 19 rows
# Data added for: 2025-03-31  -> 19 rows
# Data added for: 2025-04-01  -> 19 rows
# Data added for: 2025-04-02  -> 19 rows
# Data added for: 2025-04-03  -> 19 rows
# Data added for: 2025-04-04  -> 19 rows
# Data added for: 2025-04-05  -> 19 rows
# Data added for: 2025-04-06  -> 19 rows
# Data added for: 2025-04-07  -> 19 rows
# Data added for: 2025-04-08  -> 19 rows
# Data added for: 2025-04-09  -> 19 rows
# Data added for: 2025-04-10  -> 19 rows
# Data added for: 2025-04-11  -> 19 rows
# Data added for: 2025-04-12  -> 19 rows
# Data added for: 2025-04-13  -> 19 rows
# Data added for: 2025-04-14  -> 19 rows
# Data added for: 2025-04-15  -> 19 rows
# Data added for: 2025-04-16  -> 19 rows
# Data added for: 2025-04-17  -> 19 rows
# Data added for: 2025-04-18  -> 19 rows
# Data added for: 2025-04-19  -> 19 rows
# Data added for: 2025-04-20  -> 19 rows
# Data added for: 2025-04-21  -> 19 rows
# Data added for: 2025-04-22  -> 19 rows
# Data added for: 2025-04-23  -> 19 rows
# Data added for: 2025-04-24  -> 19 rows
# Data added for: 2025-04-25  -> 19 rows
# Data added for: 2025-04-26  -> 19 rows
# Data added for: 2025-04-27  -> 19 rows
# Data added for: 2025-04-28  -> 19 rows
# Data added for: 2025-04-29  -> 19 rows
# Data added for: 2025-04-30  -> 19 rows
# Data added for: 2025-05-01  -> 19 rows
# Data added for: 2025-05-02  -> 19 rows
# Data added for: 2025-05-03  -> 19 rows
# Data added for: 2025-05-04  -> 19 rows
# Data added for: 2025-05-05  -> 19 rows
# Data added for: 2025-05-06  -> 19 rows
# Data added for: 2025-05-07  -> 19 rows
# Data added for: 2025-05-08  -> 19 rows
# Data added for: 2025-05-09  -> 19 rows
# Data added for: 2025-05-10  -> 19 rows
# Data added for: 2025-05-11  -> 19 rows
# Data added for: 2025-05-12  -> 19 rows
# Data added for: 2025-05-13  -> 19 rows
# Data added for: 2025-05-14  -> 19 rows
# Data added for: 2025-05-15  -> 19 rows
# Data added for: 2025-05-16  -> 19 rows
# Data added for: 2025-05-17  -> 19 rows
# Data added for: 2025-05-18  -> 19 rows
# Data added for: 2025-05-19  -> 19 rows
# Data added for: 2025-05-20  -> 19 rows
# Data added for: 2025-05-21  -> 19 rows
# Data added for: 2025-05-22  -> 19 rows
# Data added for: 2025-05-23  -> 19 rows
# Data added for: 2025-05-24  -> 19 rows
# Data added for: 2025-05-25  -> 19 rows
# Data added for: 2025-05-26  -> 19 rows
# Data added for: 2025-05-27  -> 19 rows
# Data added for: 2025-05-28  -> 19 rows
# Data added for: 2025-05-29  -> 19 rows
# Data added for: 2025-05-30  -> 19 rows
# Data added for: 2025-05-31  -> 19 rows
# Data added for: 2025-06-01  -> 19 rows
# Data added for: 2025-06-02  -> 19 rows
# Data added for: 2025-06-03  -> 19 rows
# Data added for: 2025-06-04  -> 19 rows
# Data added for: 2025-06-05  -> 19 rows
# Data added for: 2025-06-06  -> 19 rows
# Data added for: 2025-06-07  -> 19 rows
# Data added for: 2025-06-08  -> 19 rows
# Data added for: 2025-06-09  -> 19 rows
# Data added for: 2025-06-10  -> 19 rows
# Data added for: 2025-06-11  -> 19 rows
# Data added for: 2025-06-12  -> 19 rows
# Data added for: 2025-06-13  -> 19 rows
# Data added for: 2025-06-14  -> 19 rows
# Data added for: 2025-06-15  -> 19 rows
# Data added for: 2025-06-16  -> 19 rows
# Data added for: 2025-06-17  -> 19 rows
# Data added for: 2025-06-18  -> 19 rows
# Data added for: 2025-06-19  -> 19 rows
# Data added for: 2025-06-20  -> 19 rows
# Data added for: 2025-06-21  -> 19 rows
# Data added for: 2025-06-22  -> 19 rows
# Data added for: 2025-06-23  -> 19 rows
# Data added for: 2025-06-24  -> 19 rows
# Data added for: 2025-06-25  -> 19 rows
# Data added for: 2025-06-26  -> 19 rows
# Data added for: 2025-06-27  -> 19 rows
# Data added for: 2025-06-28  -> 19 rows
# Data added for: 2025-06-29  -> 19 rows
# Data added for: 2025-06-30  -> 19 rows
# Data added for: 2025-07-01  -> 19 rows
# Data added for: 2025-07-02  -> 19 rows
# Data added for: 2025-07-03  -> 19 rows
# Data added for: 2025-07-04  -> 19 rows
# Data added for: 2025-07-05  -> 19 rows
# Data added for: 2025-07-06  -> 19 rows
# Data added for: 2025-07-07  -> 19 rows
# Data added for: 2025-07-08  -> 19 rows
# Data added for: 2025-07-09  -> 19 rows
# Data added for: 2025-07-10  -> 19 rows
# Data added for: 2025-07-11  -> 19 rows
# Data added for: 2025-07-12  -> 19 rows
# Data added for: 2025-07-13  -> 19 rows
# Data added for: 2025-07-14  -> 19 rows
# Data added for: 2025-07-15  -> 19 rows
# Data added for: 2025-07-16  -> 19 rows
# Data added for: 2025-07-17  -> 19 rows
# Data added for: 2025-07-18  -> 19 rows
# Data added for: 2025-07-19  -> 19 rows
# Data added for: 2025-07-20  -> 19 rows
# Data added for: 2025-07-21  -> 19 rows
# Data added for: 2025-07-22  -> 19 rows
# Data added for: 2025-07-23  -> 19 rows
# Data added for: 2025-07-24  -> 19 rows
# Data added for: 2025-07-25  -> 19 rows
# Data added for: 2025-07-26  -> 19 rows
# Data added for: 2025-07-27  -> 19 rows
# Data added for: 2025-07-28  -> 19 rows
# Data added for: 2025-07-29  -> 19 rows
# Data added for: 2025-07-30  -> 19 rows
# Data added for: 2025-07-31  -> 19 rows
# Data added for: 2025-08-01  -> 19 rows
# Data added for: 2025-08-02  -> 19 rows
# Data added for: 2025-08-03  -> 19 rows
# Data added for: 2025-08-04  -> 19 rows
# Data added for: 2025-08-05  -> 19 rows
# Data added for: 2025-08-06  -> 19 rows
# Data added for: 2025-08-07  -> 19 rows
# Data added for: 2025-08-08  -> 19 rows
# Data added for: 2025-08-09  -> 19 rows
# Data added for: 2025-08-10  -> 19 rows
# Data added for: 2025-08-11  -> 19 rows
# Data added for: 2025-08-12  -> 19 rows
# Data added for: 2025-08-13  -> 19 rows
# Data added for: 2025-08-14  -> 19 rows
# Data added for: 2025-08-15  -> 19 rows
# Data added for: 2025-08-16  -> 19 rows
# Data added for: 2025-08-17  -> 19 rows
# Data added for: 2025-08-18  -> 19 rows
# Data added for: 2025-08-19  -> 19 rows
# Data added for: 2025-08-20  -> 19 rows
# Data added for: 2025-08-21  -> 19 rows
# Data added for: 2025-08-22  -> 19 rows
# Data added for: 2025-08-23  -> 19 rows
# Data added for: 2025-08-24  -> 19 rows
# Data added for: 2025-08-25  -> 19 rows
# Data added for: 2025-08-26  -> 19 rows
# Data added for: 2025-08-27  -> 19 rows
# Data added for: 2025-08-28  -> 19 rows
# Data added for: 2025-08-29  -> 19 rows
# Data added for: 2025-08-30  -> 19 rows
# Data added for: 2025-08-31  -> 19 rows
# Data added for: 2025-09-01  -> 19 rows
# Data added for: 2025-09-02  -> 19 rows
# Data added for: 2025-09-03  -> 19 rows
# Data added for: 2025-09-04  -> 19 rows
# Data added for: 2025-09-05  -> 19 rows
# Data added for: 2025-09-06  -> 19 rows
# Data added for: 2025-09-07  -> 19 rows
# Data added for: 2025-09-08  -> 19 rows
# Data added for: 2025-09-09  -> 19 rows
# Data added for: 2025-09-10  -> 19 rows
# Data added for: 2025-09-11  -> 19 rows
# Data added for: 2025-09-12  -> 19 rows
# Data added for: 2025-09-13  -> 19 rows
# Data added for: 2025-09-14  -> 19 rows
# Data added for: 2025-09-15  -> 19 rows
# Data added for: 2025-09-16  -> 19 rows
# Data added for: 2025-09-17  -> 19 rows
# Data added for: 2025-09-18  -> 19 rows
# Data added for: 2025-09-19  -> 19 rows
# Data added for: 2025-09-20  -> 19 rows
# Data added for: 2025-09-21  -> 19 rows
# Data added for: 2025-09-22  -> 19 rows
# Data added for: 2025-09-23  -> 19 rows
# Data added for: 2025-09-24  -> 19 rows
# Data added for: 2025-09-25  -> 19 rows
# Data added for: 2025-09-26  -> 19 rows
# Data added for: 2025-09-27  -> 19 rows
# Data added for: 2025-09-28  -> 19 rows
# Data added for: 2025-09-29  -> 19 rows
# Data added for: 2025-09-30  -> 19 rows
# Data added for: 2025-10-01  -> 19 rows
# Data added for: 2025-10-02  -> 19 rows
# Data added for: 2025-10-03  -> 19 rows
# Data added for: 2025-10-04  -> 19 rows
# Data added for: 2025-10-05  -> 19 rows
# Data added for: 2025-10-06  -> 19 rows
# Data added for: 2025-10-07  -> 19 rows
# Data added for: 2025-10-08  -> 19 rows
# Data added for: 2025-10-09  -> 19 rows
# Data added for: 2025-10-10  -> 19 rows
# Data added for: 2025-10-11  -> 19 rows
# Data added for: 2025-10-12  -> 19 rows
# Data added for: 2025-10-13  -> 19 rows
# Data added for: 2025-10-14  -> 19 rows
# Data added for: 2025-10-15  -> 19 rows
# Data added for: 2025-10-16  -> 19 rows
# Data added for: 2025-10-17  -> 19 rows
# Data added for: 2025-10-18  -> 19 rows
# Data added for: 2025-10-19  -> 19 rows
# Data added for: 2025-10-20  -> 19 rows
# Data added for: 2025-10-21  -> 19 rows
# Data added for: 2025-10-22  -> 19 rows
# Data added for: 2025-10-23  -> 19 rows
# Data added for: 2025-10-24  -> 19 rows
# Data added for: 2025-10-25  -> 19 rows
# Data added for: 2025-10-26  -> 19 rows
# Data added for: 2025-10-27  -> 19 rows
# Data added for: 2025-10-28  -> 19 rows
# Data added for: 2025-10-29  -> 19 rows
# Data added for: 2025-10-30  -> 19 rows
# Data added for: 2025-10-31  -> 19 rows
# Data added for: 2025-11-01  -> 19 rows
# Data added for: 2025-11-02  -> 19 rows
# Data added for: 2025-11-03  -> 19 rows
# Data added for: 2025-11-04  -> 19 rows
# Data added for: 2025-11-05  -> 19 rows
# Data added for: 2025-11-06  -> 19 rows
# Data added for: 2025-11-07  -> 19 rows
# Data added for: 2025-11-08  -> 19 rows
# Data added for: 2025-11-09  -> 19 rows
# Data added for: 2025-11-10  -> 19 rows
# Data added for: 2025-11-11  -> 19 rows
# Data added for: 2025-11-12  -> 19 rows
# Data added for: 2025-11-13  -> 19 rows
# Data added for: 2025-11-14  -> 19 rows
# Data added for: 2025-11-15  -> 19 rows
# Data added for: 2025-11-16  -> 19 rows
# Data added for: 2025-11-17  -> 19 rows
# Data added for: 2025-11-18  -> 19 rows
# Data added for: 2025-11-19  -> 19 rows
# Data added for: 2025-11-20  -> 19 rows
# Data added for: 2025-11-21  -> 19 rows
# Data added for: 2025-11-22  -> 19 rows
# Data added for: 2025-11-23  -> 19 rows
# Data added for: 2025-11-24  -> 19 rows
# Data added for: 2025-11-25  -> 19 rows
# Data added for: 2025-11-26  -> 19 rows
# Data added for: 2025-11-27  -> 19 rows
# Data added for: 2025-11-28  -> 19 rows
# Data added for: 2025-11-29  -> 19 rows
# Data added for: 2025-11-30  -> 19 rows
# Data added for: 2025-12-01  -> 19 rows
# Data added for: 2025-12-02  -> 19 rows
# Data added for: 2025-12-03  -> 19 rows
# Data added for: 2025-12-04  -> 19 rows
# Data added for: 2025-12-05  -> 19 rows
# Data added for: 2025-12-06  -> 19 rows
# Data added for: 2025-12-07  -> 19 rows
# Data added for: 2025-12-08  -> 19 rows
# Data added for: 2025-12-09  -> 19 rows
# Data added for: 2025-12-10  -> 19 rows
# Data added for: 2025-12-11  -> 19 rows
# Data added for: 2025-12-12  -> 19 rows
# Data added for: 2025-12-13  -> 19 rows
# Data added for: 2025-12-14  -> 19 rows
# Data added for: 2025-12-15  -> 19 rows
# Data added for: 2025-12-16  -> 19 rows
# Data added for: 2025-12-17  -> 19 rows
# Data added for: 2025-12-18  -> 19 rows
# Data added for: 2025-12-19  -> 19 rows
# Data added for: 2025-12-20  -> 19 rows
# Data added for: 2025-12-21  -> 19 rows
# Data added for: 2025-12-22  -> 19 rows
# Data added for: 2025-12-23  -> 19 rows
# Data added for: 2025-12-24  -> 19 rows
# Data added for: 2025-12-25  -> 19 rows
# Data added for: 2025-12-26  -> 19 rows
# Data added for: 2025-12-27  -> 19 rows
# Data added for: 2025-12-28  -> 19 rows
# Data added for: 2025-12-29  -> 19 rows
# Data added for: 2025-12-30  -> 19 rows
# Data added for: 2025-12-31  -> 19 rows
# ✅ Saved as dam_data_2015_2025.csv
# Total rows: 25042

# %%
# while getting ip blokage in web scrapping i stored the generated data here.
pd.DataFrame(
    all_data,
    columns=[
        "Date", "Reservoirs", "Full Depth", "Full Capacity",
        "Current Level", "Current Storage",
        "Inflow", "Outflow",
        "Last Year Level", "Last Year Storage"
    ]
).to_csv("dam_data_emergency_save.csv", index=False)

# also there will be anotehr file which is generated after scrapping the remaning data.

# %%
# I am combining both csv generated befored and after emergency.
import pandas as pd

# Load both CSV files
df1 = pd.read_csv("dam_data_emergency_save.csv")
df2 = pd.read_csv("dam_data_2015_2025.csv")

print("File 1 rows:", len(df1))
print("File 2 rows:", len(df2))

# Combine both datasets
combined_df = pd.concat([df1, df2], ignore_index=True)

# Remove exact duplicate rows
combined_df.drop_duplicates(inplace=True)

# If you have a Date column, sort by it
if "Date" in combined_df.columns:
    combined_df["Date"] = pd.to_datetime(combined_df["Date"], errors="coerce")
    combined_df.sort_values("Date", inplace=True)

# Reset index after cleaning
combined_df.reset_index(drop=True, inplace=True)

# Save final merged file
final_file = "dam_data_2015_2025_with_error.csv"
combined_df.to_csv(final_file, index=False)

print("Final rows:", len(combined_df))
print("Saved as:", final_file)
# Out:
# File 1 rows: 51287
# File 2 rows: 25042
# Final rows: 76279
# Saved as: dam_data_2015_2025_final.csv

# %% [markdown]
# ## Success in combination with a problem.
# 1. After doing all the efforts for the extracting data I successfully scraped all the 76279 rows from the government website after 4000 hits on the websites.
# 2. The problem is both files have differnt column names. So, they are not combining properly they are making differnt columns after row number 51287. It means we are getting 20 columsn and its a big problem.
# ## My solution on the problem
# 1. Standardizing the column names in the both files.
# 2. Combining both files with simple column names
# 3. studying the columns units and columns itself for further process.

# %%
# standerdizing the columns
standard_columns = [
    "date",
    "dam_name",
    "full_depth",
    "full_capacity",
    "current_level",
    "current_storage",
    "current_inflow",
    "current_outflow",
    "Last Year Level(Feet)",
    "Last Year Storage(M.Cft.)"
]

# %%
# writing a function to standerdize the files columsn
def standerdize_columns(input_file,output_file):
    df=pd.read_csv(input_file)

    if len(df.columns)!=len(standard_columns):
        raise ValueError(f'column count missmatch in {input_file}')

    df.columns=standard_columns
    df.to_csv(output_file,index=False) # while merging both files we add index

    print(f'Standerdized and saved: {output_file}')

# %%
# my first file which was saved in emergency of ip adderss block is standardized with the columns
standerdize_columns("dam_data_emergency_save.csv","dam_data_emergency_standard.csv")
# Out:
# Standerdized and saved: dam_data_emergency_standard.csv

# %%
# my second file after emergency standerdized columns
standerdize_columns("dam_data_2015_2025.csv","dam_data_2015_2025_standard.csv")
# Out:
# Standerdized and saved: dam_data_2015_2025_standard.csv

# %%
# combining the standerdized columns files
# loding both csv files
df1=pd.read_csv("dam_data_emergency_standard.csv")
df2=pd.read_csv("dam_data_2015_2025_standard.csv")

print("length of rows in file 1 : {}".format(len(df1)))
print("length of rows in file 2 : {}".format(len(df2)))

# combining both files
combined_df=pd.concat([df1,df2],ignore_index=True)

# removing the duplicate rows
combined_df.drop_duplicates(inplace=True)

# sorting date column
if "date" in combined_df.columns:
    combined_df["date"]=pd.to_datetime(combined_df["date"],errors="coerce")
    combined_df.sort_values("date",inplace=True)

# Reseting the index
combined_df.reset_index(drop=True,inplace=True) # drop=True for the removing old index.

# giving name to file and converting it to csv
file_name="dam_data_final.csv"   # alwaays give .csv other wise you get normal data with commmas
combined_df.to_csv(file_name,index=False) # index=False to maek data more clear. at last before sending data to ml we clear the index

print("Final rows after combination : ", len(combined_df))
print("Final combined file saved as : ",file_name)
# Out:
# length of rows in file 1 : 51287
# length of rows in file 2 : 25042
# Final rows after combination :  76279
# Final combined file saved as :  dam_data_final.csv
