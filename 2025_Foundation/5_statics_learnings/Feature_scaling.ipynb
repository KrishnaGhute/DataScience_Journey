# %% [markdown]
# ## Normilization:
# - scale down the feature between 0 to 1.
# - x_normal=(x - x_min)/(x_max - x_min)
# ## Standerdization:
# - scale down the feature based on the stand normal distribution (mean=0 and std=1).
# - z=(x - u)/std

# %%
import numpy as np
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\krish\\statics_learnings'

# %%
# Load the CSV
df = pd.read_csv(r"C:\Users\krish\wine.csv",header=None,usecols=[1,2,3])
df.columns=["Class","Alcohol","Malic"]
# Check the first few rows
df.head()
# Out:
#    Class  Alcohol  Malic
# 0      0     1.00   2.00
# 1      1    14.23   1.71
# 2      1    13.20   1.78
# 3      1    13.16   2.36
# 4      1    14.37   1.95

# %%
print(df.head())
print(df.shape)
print(df.describe())
# Out:
#    Class  Alcohol  Malic
# 0      0     1.00   2.00
# 1      1    14.23   1.71
# 2      1    13.20   1.78
# 3      1    13.16   2.36
# 4      1    14.37   1.95
# (179, 3)
#             Class     Alcohol       Malic
# count  179.000000  179.000000  179.000000
# mean     1.927374   12.933575    2.334469
# std      0.786315    1.208268    1.114287
# min      0.000000    1.000000    0.740000
# 25%      1.000000   12.350000    1.605000
# 50%      2.000000   13.050000    1.870000
# 75%      3.000000   13.675000    3.065000
# max      3.000000   14.830000    5.800000

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaling=MinMaxScaler()

# %%
scaling.fit_transform(df[['Alcohol','Malic']])
# Out:
# array([[0.        , 0.24901186],
#        [0.95661605, 0.1916996 ],
#        [0.88214027, 0.2055336 ],
#        [0.87924801, 0.3201581 ],
#        [0.96673897, 0.23913043],
#        [0.88503254, 0.36561265],
#        [0.95444685, 0.20158103],
#        [0.9681851 , 0.22332016],
#        [0.94432393, 0.27865613],
#        [1.        , 0.17786561],
#        [0.92986262, 0.12055336],
#        [0.9472162 , 0.28063241],
#        [0.94866233, 0.14624506],
#        [0.92190889, 0.19565217],
#        [0.99421547, 0.19565217],
#        [0.96746204, 0.22332016],
#        [0.9132321 , 0.21146245],
#        [0.96167751, 0.23320158],
#        [0.92769342, 0.16403162],
#        [0.95372379, 0.16798419],
#        [0.91395517, 0.46640316],
#        [0.94432393, 0.17588933],
#        [0.8626175 , 0.60474308],
#        [0.91901663, 0.22134387],
#        [0.85683297, 0.16996047],
#        [0.90383225, 0.21146245],
#        [0.87129429, 0.25889328],
#        [0.89587852, 0.20355731],
# ...

# %% [markdown]
# ## standardization(Z-score Normilization)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaling=StandardScaler()

# %%
scaling.fit_transform(df[['Alcohol','Malic']])
# Out:
# array([[-9.90429979e+00, -3.01006294e-01],
#        [ 1.07597072e+00, -5.61992376e-01],
#        [ 2.21119726e-01, -4.98995736e-01],
#        [ 1.87921629e-01,  2.29764283e-02],
#        [ 1.19216406e+00, -3.46003895e-01],
#        [ 2.54317822e-01,  2.29965390e-01],
#        [ 1.05107215e+00, -5.16994776e-01],
#        [ 1.20876311e+00, -4.18000055e-01],
#        [ 9.34878807e-01, -1.66013493e-01],
#        [ 1.57394217e+00, -6.24989017e-01],
#        [ 7.68888323e-01, -8.85975099e-01],
#        [ 9.68076903e-01, -1.57013973e-01],
#        [ 9.84675952e-01, -7.68981338e-01],
#        [ 6.77593557e-01, -5.43993336e-01],
#        [ 1.50754598e+00, -5.43993336e-01],
#        [ 1.20046358e+00, -4.18000055e-01],
#        [ 5.77999266e-01, -4.71997176e-01],
#        [ 1.13406739e+00, -3.73002455e-01],
#        [ 7.43989750e-01, -6.87985658e-01],
#        [ 1.04277262e+00, -6.69986617e-01],
#        [ 5.86298790e-01,  6.88940914e-01],
#        [ 9.34878807e-01, -6.33988537e-01],
# ...
