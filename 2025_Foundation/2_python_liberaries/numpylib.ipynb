# %%
import numpy as np
print(np.__version__)
# Out:
# 2.1.3

# %%
my_list=[2,4,3,7,5,4]
arr=np.array(my_list)
print(arr)
# Out:
# [2 4 3 7 5 4]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
arr.shape
# Out:
# (6,)

# %%
l1=[1,4,2,5,6]
l2=[1,3,2,3,6]
l3=[3,5,2,6,3]
arr=np.array([[l1,l2,l3]])
print(arr)
# Out:
# [[[1 4 2 5 6]
#   [1 3 2 3 6]
#   [3 5 2 6 3]]]

# %%
arr.shape
# Out:
# (1, 3, 5)

# %%
print(arr[0:2,2])
# Out:
# [[3 5 2 6 3]]

# %%
arr.reshape(5,3)
# Out:
# array([[1, 4, 2],
#        [5, 6, 1],
#        [3, 2, 3],
#        [6, 3, 5],
#        [2, 6, 3]])

# %%
print(arr.ndim)
# Out:
# 3

# %%
arr.reshape(1,15)
# Out:
# array([[1, 4, 2, 5, 6, 1, 3, 2, 3, 6, 3, 5, 2, 6, 3]])

# %%
arr[:,:]
# Out:
# array([[[1, 4, 2, 5, 6],
#         [1, 3, 2, 3, 6],
#         [3, 5, 2, 6, 3]]])

# %%
arr[0:2,0:2]
# Out:
# array([[[1, 4, 2, 5, 6],
#         [1, 3, 2, 3, 6]]])

# %%
arr[1:3,3:5]
# Out:
# array([], shape=(0, 0, 5), dtype=int64)

# %%
arr=np.arange(0,10,step=2)
print(arr)
# Out:
# [0 2 4 6 8]

# %%
arr=np.linspace(1,2,50)
arr
# Out:
# array([1.        , 1.02040816, 1.04081633, 1.06122449, 1.08163265,
#        1.10204082, 1.12244898, 1.14285714, 1.16326531, 1.18367347,
#        1.20408163, 1.2244898 , 1.24489796, 1.26530612, 1.28571429,
#        1.30612245, 1.32653061, 1.34693878, 1.36734694, 1.3877551 ,
#        1.40816327, 1.42857143, 1.44897959, 1.46938776, 1.48979592,
#        1.51020408, 1.53061224, 1.55102041, 1.57142857, 1.59183673,
#        1.6122449 , 1.63265306, 1.65306122, 1.67346939, 1.69387755,
#        1.71428571, 1.73469388, 1.75510204, 1.7755102 , 1.79591837,
#        1.81632653, 1.83673469, 1.85714286, 1.87755102, 1.89795918,
#        1.91836735, 1.93877551, 1.95918367, 1.97959184, 2.        ])

# %%
import matplotlib.pyplot as plt
plt.plot(arr)
plt.show()

# %%
import numpy as np
lst=[1,2,3,4,5,6,7,8,9]
arr=np.array(lst)
arr1=arr
print(arr1)
arr1[3:6]=100
print(arr1)
# Out:
# [1 2 3 4 5 6 7 8 9]
# [  1   2   3 100 100 100   7   8   9]

# %%
arr1=arr.copy()
print(arr)
arr1[3:6]=500
print(arr1)
print(arr)
# Out:
# [  1   2   3 100 100 100   7   8   9]
# [  1   2   3 500 500 500   7   8   9]
# [  1   2   3 100 100 100   7   8   9]

# %%
#usefull conditions in exploratory data analysis 
arr>5
# Out:
# array([False, False, False,  True,  True,  True,  True,  True,  True])

# %%
arr**2
# Out:
# array([    1,     4,     9, 10000, 10000, 10000,    49,    64,    81])

# %%
arr[arr>5]
# Out:
# array([100, 100, 100,   7,   8,   9])

# %%
arr2=np.arange(1,7).reshape(2,3)
print(arr2)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
arr3=np.ones(5,dtype=float)
print(arr3)
# Out:
# [1. 1. 1. 1. 1.]

# %%
arr4=np.ones(5,dtype=int)
print(arr4)
# Out:
# [1 1 1 1 1]

# %%
arr4=np.random.rand(3,3)
print(arr4)
# Out:
# [[0.23242471 0.49136346 0.90229893]
#  [0.72688086 0.76430233 0.39188647]
#  [0.86438168 0.28449386 0.31107592]]

# %%
arr5=np.random.randn(4,4)
print(arr5)
# Out:
# [[-0.06283701  0.23871323 -0.78513973  0.14062384]
#  [-0.0340393   0.57615746 -0.27661998  0.85866793]
#  [ 2.52736654 -1.50935627  0.40745056 -0.8308463 ]
#  [-1.63427824  0.6294307  -0.05170967  3.17921561]]

# %%
np.random.randint(0,100,10).reshape(5,2)
# Out:
# array([[70, 31],
#        [76, 78],
#        [63, 99],
#        [29, 31],
#        [82, 89]], dtype=int32)
