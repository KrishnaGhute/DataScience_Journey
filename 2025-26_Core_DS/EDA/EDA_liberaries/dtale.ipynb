# %% [markdown]
# # dtale

# %%
pip install dtale

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
df=pd.read_csv("titanic_train.csv")

# %%
df.head()

# %%
import dtale
dtale.show(df)
